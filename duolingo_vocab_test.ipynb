# %%
import duolingo
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
duo = duolingo.Duolingo(username='KhoaLam12', password='Hnivaohk1')
vocab = duo.get_vocabulary('de')['vocab_overview']
words = [(w['word_string'], w['pos'], w.get('gender'), w.get('infinitive')) for w in vocab]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ade9b6df0afd> in <module>()
# ----> 1 duo = duolingo.Duolingo(username='KhoaLam12', password='Hnivaohk1')
#       2 vocab = duo.get_vocabulary('de')['vocab_overview']
#       3 words = [(w['word_string'], w['pos'], w.get('gender'), w.get('infinitive')) for w in vocab]
#
# ~/anaconda3/lib/python3.6/site-packages/duolingo.py in __init__(self, username, password, jwt, session_file)
#      68             raise DuolingoException("Password, jwt, or session_file must be specified in order to authenticate.")
#      69
# ---> 70         self.user_data = Struct(**self._get_data())
#      71         self.voice_url_dict = None
#      72
#
# ~/anaconda3/lib/python3.6/site-packages/duolingo.py in _get_data(self)
#     258         Get user's data from ``https://www.duolingo.com/users/<username>``.
#     259         """
# ...

# %%
from pattern import de

# %%
de.attributive('müde')
# Out:
# 'müdeer'
